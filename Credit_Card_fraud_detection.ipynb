# %% [markdown]
# <a href="https://colab.research.google.com/github/SanthanaNarayanan-git/Codsoft_intern_projects/blob/main/Credit_Card_fraud_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler

credit_card_data = pd.read_csv('creditcard.csv')
credit_card_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
credit_card_data.tail()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 13949  24754  1.252924 -0.182189 -0.802716 -0.210981  1.916713  3.643624
# 13950  24756 -0.346979 -2.103284 -0.685061  1.961605 -0.401125  0.473632
# 13951  24759 -6.053652 -5.988723  0.810413 -0.011811  1.308135 -0.590803
# 13952  24759  1.169121 -1.284945  0.032717 -0.681670  0.660598  4.412578
# 13953  24759 -6.917152  5.854171 -1.652458 -1.488884 -0.833891 -0.344418
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 13949 -0.778711  0.818295  1.706962  ... -0.497088 -1.211285  0.043809
# 13950  1.133816 -0.256528  0.893409  ...  0.359662 -0.316275 -0.864259
# 13951 -0.725838 -0.234840  1.624646  ... -0.771970  1.474668  3.176363
# 13952 -1.913115  1.076592  1.501230  ... -0.557596 -0.882435 -0.041523
# 13953  0.393789  0.379968  6.133597  ... -1.404681 -1.124694  0.174333
#
#             V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
credit_card_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13954 entries, 0 to 13953
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    13954 non-null  int64
#  1   V1      13954 non-null  float64
#  2   V2      13954 non-null  float64
#  3   V3      13954 non-null  float64
#  4   V4      13954 non-null  float64
#  5   V5      13954 non-null  float64
#  6   V6      13954 non-null  float64
#  7   V7      13954 non-null  float64
#  8   V8      13954 non-null  float64
#  9   V9      13954 non-null  float64
#  10  V10     13954 non-null  float64
#  11  V11     13954 non-null  float64
#  12  V12     13954 non-null  float64
#  13  V13     13954 non-null  float64
#  14  V14     13954 non-null  float64
#  15  V15     13954 non-null  float64
#  16  V16     13954 non-null  float64
#  17  V17     13954 non-null  float64
#  18  V18     13954 non-null  float64
#  19  V19     13954 non-null  float64
# ...

# %%
credit_card_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    1
# Class     1
# dtype: int64

# %%
#distribution of logic and fraud
credit_card_data['Class'].value_counts()
# Out:
# Class
# 0.0    13897
# 1.0       56
# Name: count, dtype: int64

# %%
legid = credit_card_data[credit_card_data.Class == 0]
fraud = credit_card_data[credit_card_data.Class == 1]

# %%
print(legid.shape)
print(fraud.shape)
# Out:
# (13897, 31)
# (56, 31)

# %%
legid.Amount.describe()
# Out:
# count    13897.000000
# mean        63.773909
# std        177.164503
# min          0.000000
# 25%          5.770000
# 50%         15.900000
# 75%         52.370000
# max       7712.430000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count      56.000000
# mean       90.815893
# std       310.308450
# min         0.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.025000
# max      1809.680000
# Name: Amount, dtype: float64

# %%
#compare the values for both transaction
credit_card_data.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0.0    10111.481255 -0.217093  0.266252  0.887227  0.276789 -0.107510
# 1.0    12262.107143 -4.727948  4.660436 -9.328536  6.783464 -2.890388
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.136745 -0.131462 -0.020385  1.005460  ...  0.020758 -0.068686
# 1.0   -2.030360 -6.578337  1.028374 -2.981468  ...  0.453283  0.116896
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.158230 -0.034834  0.013065  0.117928  0.034349  0.009565  0.002329
# 1.0    0.048132 -0.225526 -0.452514 -0.124184  0.333325  0.793484 -0.046177
#
#           Amount
# Class
# 0.0    63.773909
# 1.0    90.815893
#
# [2 rows x 30 columns]

# %%
#same num of fraud and normal transaction

# %%
legid_sample = legid.sample(n = 492)
#add row wise
new_dataset = pd.concat([legid_sample,fraud],axis = 0 )
new_dataset.head()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 10977  18884 -0.903371 -0.080855  0.390673 -0.887894  1.814754 -0.725341
# 7877   10949  1.227416 -0.004864  0.771010  0.126015 -0.549528 -0.308661
# 541      406 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 623      472 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
# 4920    4462 -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 10977  0.328375 -0.072970  0.701775  ... -0.100085 -0.265592  0.010180
# 7877  -0.495784 -0.077347  1.388186  ... -0.028132  0.181258 -0.078065
# 541   -2.537387  1.391657 -2.770089  ...  0.517232 -0.035049 -0.465211
# 623    0.325574 -0.067794 -0.270953  ...  0.661696  0.435477  1.375966
# 4920   0.562320 -0.399147 -0.238253  ... -0.294166 -0.932391  0.172726
#
#             V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
new_dataset['Class'].value_counts()
# Out:
# Class
# 1.0    56
# 0.0     2
# Name: count, dtype: int64

# %%
#if the mean are nearby then it is good if not it is bad
new_dataset.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0.0    14916.500000  0.162022 -0.042859  0.580841 -0.380940  0.632613
# 1.0    12262.107143 -4.727948  4.660436 -9.328536  6.783464 -2.890388
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0   -0.517001 -0.083704 -0.075158  1.044980  ...  0.209860 -0.064109
# 1.0   -2.030360 -6.578337  1.028374 -2.981468  ...  0.453283  0.116896
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.042167 -0.033943 -0.488711  0.117421  0.932456  0.020186  0.045839
# 1.0    0.048132 -0.225526 -0.452514 -0.124184  0.333325  0.793484 -0.046177
#
#           Amount
# Class
# 0.0    30.470000
# 1.0    90.815893
#
# [2 rows x 30 columns]

# %%
#spliting the data into features and target
X = new_dataset.drop(columns='Class',axis = 1)
Y = new_dataset['Class']

# %%
#columns only
print(X)
# Out:
#         Time         V1         V2         V3         V4         V5        V6  \
# 10977  18884  -0.903371  -0.080855   0.390673  -0.887894   1.814754 -0.725341
# 7877   10949   1.227416  -0.004864   0.771010   0.126015  -0.549528 -0.308661
# 541      406  -2.312227   1.951992  -1.609851   3.997906  -0.522188 -1.426545
# 623      472  -3.043541  -3.157307   1.088463   2.288644   1.359805 -1.064823
# 4920    4462  -2.303350   1.759247  -0.359745   2.330243  -0.821628 -0.075788
# 6108    6986  -4.397974   1.358367  -2.592844   2.679787  -1.128131 -1.706536
# 6329    7519   1.234235   3.019740  -4.304597   4.732795   3.624201 -1.357746
# 6331    7526   0.008430   4.137837  -6.240697   6.675732   0.768307 -3.353060
# 6334    7535   0.026779   4.132464  -6.560600   6.348557   1.329666 -2.513479
# 6336    7543   0.329594   3.712889  -5.775935   6.078266   1.667359 -2.420168
# 6338    7551   0.316459   3.809076  -5.615159   6.047445   1.554026 -2.651353
# ...

# %%
#contains rows only
print(Y)
# Out:
# 10977    0.0
# 7877     0.0
# 541      1.0
# 623      1.0
# 4920     1.0
# 6108     1.0
# 6329     1.0
# 6331     1.0
# 6334     1.0
# 6336     1.0
# 6338     1.0
# 6427     1.0
# 6446     1.0
# 6472     1.0
# 6529     1.0
# 6609     1.0
# 6641     1.0
# 6717     1.0
# 6719     1.0
# 6734     1.0
# 6774     1.0
# 6820     1.0
# 6870     1.0
# 6882     1.0
# 6899     1.0
# 6903     1.0
# 6971     1.0
# 8296     1.0
# 8312     1.0
# 8335     1.0
# 8615     1.0
# 8617     1.0
# 8842     1.0
# 8845     1.0
# 8972     1.0
# 9035     1.0
# 9179     1.0
# 9252     1.0
# 9487     1.0
# 9509     1.0
# 10204    1.0
# 10484    1.0
# 10497    1.0
# 10498    1.0
# 10568    1.0
# 10630    1.0
# 10690    1.0
# 10801    1.0
# 10891    1.0
# 10897    1.0
# 11343    1.0
# 11710    1.0
# 11841    1.0
# 11880    1.0
# 12070    1.0
# 12108    1.0
# 12261    1.0
# 12369    1.0
# Name: Class, dtype: float64

# %%
#devide into train and test data
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.2, stratify=Y, random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (58, 30) (46, 30) (12, 30)

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
#logistic regression
model = LogisticRegression(max_iter=115)

# %%
#training the logistic regression model
model.fit(X_train, Y_train)
# Out:
# LogisticRegression(max_iter=115)

# %%
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)
print(training_data_accuracy)
# Out:
# 1.0

# %%
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)
print(test_data_accuracy)
# Out:
# 1.0
